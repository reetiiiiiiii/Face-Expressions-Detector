# %%
import cv2
import matplotlib.pyplot as plt

# %%
pip install deepface

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab import drive
drive.mount('/content/drive')
img = cv2.imread('/content/drive/MyDrive/riti.jpg')
plt.imshow(img[:,:,::-1])
plt.show()
# Out:
# Mounted at /content/drive

# %%
result = DeepFace.analyze(img, actions = ['emotion'])

# %%
print(result)
# Out:
# {'emotion': {'angry': 0.00097828999808046, 'disgust': 1.1706212396039845e-08, 'fear': 0.0018224837175481168, 'happy': 99.15068735488502, 'sad': 0.01132180758210958, 'surprise': 0.0070411225559783045, 'neutral': 0.828155322003999}, 'dominant_emotion': 'happy', 'region': {'x': 296, 'y': 169, 'w': 395, 'h': 395}}
